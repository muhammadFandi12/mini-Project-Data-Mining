# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadFandi12/mini-Project-Data-Mining/blob/main/Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Apple Quality**

# %% [markdown]
# ## **Business Understanding**

# %% [markdown]
# **Business Objective**
#
# Tujuan dari Bisnis ini adalah Meningkatkan kualitas apel untuk meningkatkan kepuasan pelanggan dan daya saing pasar. Ini mencakup peningkatan kesegaran, rasa, dan nilai gizi apel, serta pengurangan cacat dan kerusakan.

# %% [markdown]
# **Assess Situation**
#
# Kualitas apel saat ini mungkin tidak konsisten di pasar. Pelanggan semakin memprioritaskan produk segar dan berkualitas tinggi, dan pesaing mungkin sudah menginvestasikan kontrol kualitas. Rantai pasokan apel harus dianalisis untuk mengidentifikasi titik potensial degradasi kualitas, mulai dari panen hingga distribusi.

# %% [markdown]
# **Data Mining Goals**
#
# Data tentang kualitas apel harus dikumpulkan dari pemasok, distributor, dan umpan balik pelanggan. Analisis data menggunakan metode statistik dan pembelajaran mesin untuk mengidentifikasi pola dan faktor yang memengaruhi kualitas apel. Model prediktif dapat dikembangkan untuk memprediksi kualitas apel berdasarkan faktor-faktor seperti kondisi panen, transportasi, dan metode penyimpanan. Wawasan yang diperoleh dari model harus dapat diubah menjadi strategi yang dapat diambil tindakan.

# %% [markdown]
# **Project Plan**
#
# Proyek harus terdiri dari beberapa tahap: pengumpulan data, analisis data, pembuatan model, dan implementasi strategi. Setiap tahap harus diberi waktu yang cukup untuk menyelesaikannya dengan baik. Setelah model selesai, strategi berdasarkan wawasan model harus diimplementasikan dan dievaluasi untuk efektivitasnya.

# %%
import pandas as pd

# %%
df = pd.read_csv("apple_quality.csv")

df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['A_id'].plot(kind='hist', bins=20, title='A_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['Size'].plot(kind='hist', bins=20, title='Size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Sweetness'].plot(kind='hist', bins=20, title='Sweetness')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_25.groupby('Acidity').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_26.groupby('Quality').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='A_id', y='Size', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='Size', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='Weight', y='Sweetness', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='Sweetness', y='Crunchiness', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['A_id']
#   ys = series['Size']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('A_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Acidity')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Acidity', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('A_id')
# _ = plt.ylabel('Size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['A_id']
#   ys = series['Size']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('A_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Quality')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Quality', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('A_id')
# _ = plt.ylabel('Size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['A_id']
#   ys = series['Weight']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('A_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Acidity')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Acidity', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('A_id')
# _ = plt.ylabel('Weight')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['A_id']
#   ys = series['Weight']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('A_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Quality')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Quality', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('A_id')
# _ = plt.ylabel('Weight')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35['A_id'].plot(kind='line', figsize=(8, 4), title='A_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['Size'].plot(kind='line', figsize=(8, 4), title='Size')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['Sweetness'].plot(kind='line', figsize=(8, 4), title='Sweetness')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Quality'].value_counts()
#     for x_label, grp in _df_39.groupby('Acidity')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Acidity')
# _ = plt.ylabel('Quality')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_40['Acidity'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_40, x='A_id', y='Acidity', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_41['Quality'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_41, x='A_id', y='Quality', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['Acidity'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='Size', y='Acidity', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['Quality'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='Size', y='Quality', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
